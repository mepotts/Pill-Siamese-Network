# %% [markdown]
# # Pill Demo

# %%
from helper_functions import *

# %%
net = SiameseNetwork()

# %%
net.load_state_dict(torch.load('mytraining.pt'))

# %% [markdown]
# ## Similar Conditions

# %%
find_inventory_match("CLA_CROPPED.jpg", net)
# Out:
# CLA_CROPPED CLA-inventory_CROPPED
# Total inference time: 0.36115503311157227s

# %%
find_inventory_match("tumeric-even-light_CROPPED.jpg", net)
# Out:
# tumeric-even-light_CROPPED tumeric-uneven-light_CROPPED
# Total inference time: 0.30559515953063965s

# %%
find_inventory_match("b-complex_CROPPED.jpg", net)
# Out:
# b-complex_CROPPED b-complex-inventory_CROPPED
# Total inference time: 0.28923702239990234s

# %%
find_inventory_match("multi-vitamin_CROPPED.jpg", net)
# Out:
# multi-vitamin_CROPPED omemag-2_CROPPED
# Total inference time: 0.30846500396728516s

# %%
find_inventory_match("aller-tec-1_CROPPED.jpg", net)
# Out:
# aller-tec-1_CROPPED tumeric-uneven-light_CROPPED
# Total inference time: 0.321566104888916s

# %%
find_inventory_match("ibuprofen_CROPPED.jpg", net)
# Out:
# ibuprofen_CROPPED ibuprofen-inventory_CROPPED
# Total inference time: 0.3070688247680664s

# %%
find_inventory_match("b12-1_CROPPED.jpg", net)
# Out:
# b12-1_CROPPED b-complex-inventory_CROPPED
# Total inference time: 0.3016500473022461s

# %%
find_inventory_match("naproxen-sodium-1_CROPPED.jpg", net)
# Out:
# naproxen-sodium-1_CROPPED naproxen-sodium_CROPPED
# Total inference time: 0.3033139705657959s

# %%
find_inventory_match("omemag-1_CROPPED.jpg", net)
# Out:
# omemag-1_CROPPED tumeric-uneven-light_CROPPED
# Total inference time: 0.30571985244750977s

# %% [markdown]
# ## Different Conditions

# %%
find_inventory_match("b-complex-dark-background_CROPPED.jpg", net)
# Out:
# b-complex-dark-background_CROPPED tumeric-uneven-light_CROPPED
# Total inference time: 0.30736398696899414s

# %%
find_inventory_match("CLA-dark-background_CROPPED.jpg", net)

# %%
find_inventory_match("ibuprofen-dark-background-1_CROPPED.jpg", net)
